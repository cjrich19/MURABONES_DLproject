# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import GroupShuffleSplit
from PIL import Image
import matplotlib.pyplot as plt
import os

# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !unzip '/content/drive/MyDrive/MURA-v1.1.zip' -d '/content/'
# Out:
# Streaming output truncated to the last 5000 lines.
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01061/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01061/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01061/study1_positive/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01061/study1_positive/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01061/study1_positive/image2.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01016/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01016/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01016/study1_positive/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01016/study1_positive/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01016/study1_positive/image2.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01182/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01182/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01182/study1_positive/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01182/study1_positive/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01182/study1_positive/image2.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00690/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00690/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00690/study1_positive/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00690/study1_positive/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00690/study1_positive/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02030/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02030/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02030/study1_negative/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00704/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00704/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00704/study1_positive/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00704/study1_positive/image4.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00704/study1_positive/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00704/study1_positive/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00773/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00773/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00773/study1_positive/image4.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00773/study1_positive/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00773/study1_positive/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00773/study1_positive/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02047/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02047/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02047/study1_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02047/study1_negative/image4.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02047/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02047/study1_negative/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00609/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00609/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00609/study1_positive/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00609/study1_positive/image4.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00609/study1_positive/image5.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00609/study1_positive/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00609/study1_positive/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00040/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00040/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00040/study1_positive/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00040/study1_positive/image4.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00040/study1_positive/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00040/study1_positive/image2.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00037/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00037/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00037/study1_positive/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00037/study1_positive/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00037/study1_positive/image3.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02679/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02679/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02679/study1_negative/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02679/study1_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02679/study1_negative/image2.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01725/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01725/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01725/study1_negative/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01725/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01725/study1_negative/image4.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01725/study1_negative/image3.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01752/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01752/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01752/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01752/study1_negative/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01628/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01628/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01628/study1_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01628/study1_negative/image4.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01628/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01628/study1_negative/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02344/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02344/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02344/study1_negative/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02344/study1_negative/image2.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00470/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00470/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00470/study1_positive/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00470/study1_positive/image4.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00470/study1_positive/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00470/study1_positive/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00407/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00407/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00407/study1_positive/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00407/study1_positive/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00407/study1_positive/image3.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02333/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02333/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02333/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02333/study1_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02333/study1_negative/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00593/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00593/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00593/study1_positive/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00593/study1_positive/image4.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00593/study1_positive/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00593/study1_positive/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02249/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02249/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02249/study1_negative/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02249/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02249/study1_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02249/study1_negative/image4.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00927/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00927/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00927/study1_positive/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00927/study1_positive/image4.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00927/study1_positive/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00927/study1_positive/image2.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00950/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00950/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00950/study1_positive/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00950/study1_positive/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00950/study1_positive/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01281/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01281/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01281/study1_positive/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01281/study1_positive/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01281/study1_positive/image3.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01281/study2_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01281/study2_negative/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01315/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01315/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01315/study1_positive/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01315/study1_positive/image4.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01315/study1_positive/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01315/study1_positive/image2.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01362/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01362/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01362/study1_positive/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01362/study1_positive/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01362/study1_positive/image4.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01362/study1_positive/image3.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01218/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01218/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01218/study1_positive/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02339/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02339/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02339/study1_negative/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02339/study1_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02339/study1_negative/image2.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00599/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00599/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00599/study1_positive/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00599/study1_positive/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00599/study2_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00599/study2_negative/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00857/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00857/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00857/study1_positive/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00857/study1_positive/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00857/study1_positive/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00820/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00820/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00820/study1_positive/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00820/study1_positive/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00820/study1_positive/image3.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00494/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00494/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00494/study1_positive/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00494/study1_positive/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00494/study1_positive/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00500/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00500/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00500/study1_positive/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00500/study1_positive/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02234/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02234/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02234/study1_negative/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02243/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02243/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02243/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02243/study1_negative/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00577/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00577/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00577/study1_positive/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00577/study1_positive/image2.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01368/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01368/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01368/study1_positive/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01368/study1_positive/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01368/study1_positive/image4.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01368/study1_positive/image2.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01265/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01265/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01265/study1_positive/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01212/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01212/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01212/study1_positive/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01212/study1_positive/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01212/study1_positive/image2.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01386/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01386/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01386/study1_positive/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01386/study1_positive/image2.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02604/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02604/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02604/study1_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02604/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02604/study1_negative/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00130/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00130/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00130/study1_positive/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00130/study1_positive/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00130/study1_positive/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00130/study1_positive/image4.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00147/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00147/study3_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00147/study3_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00147/study3_negative/image4.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00147/study3_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00147/study3_negative/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00147/study4_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00147/study4_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00147/study4_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00147/study4_negative/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00147/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00147/study1_positive/image4.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00147/study1_positive/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00147/study1_positive/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00147/study1_positive/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00147/study2_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00147/study2_positive/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00147/study2_positive/image4.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00147/study2_positive/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00147/study2_positive/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02673/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02673/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02673/study1_negative/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02673/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02673/study1_negative/image3.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01758/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01758/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01758/study1_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01758/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01758/study1_negative/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01655/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01655/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01655/study1_negative/image4.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01655/study1_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01655/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01655/study1_negative/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01622/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01622/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01622/study1_negative/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01622/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01622/study1_negative/image3.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00298/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00298/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00298/study1_positive/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00298/study1_positive/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00298/study1_positive/image3.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00298/study2_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00298/study2_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00298/study2_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00298/study2_negative/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02438/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02438/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02438/study1_negative/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02438/study1_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02438/study1_negative/image4.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02438/study1_negative/image2.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02535/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02535/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02535/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02535/study1_negative/image4.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02535/study1_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02535/study1_negative/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00201/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00201/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00201/study1_positive/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00201/study1_positive/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00201/study1_positive/image4.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00201/study1_positive/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00395/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00395/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00395/study1_positive/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00395/study1_positive/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00395/study1_positive/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00276/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00276/study2_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00276/study2_positive/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00276/study2_positive/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00276/study2_positive/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00276/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00276/study1_positive/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00276/study1_positive/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00276/study1_positive/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02542/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02542/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02542/study1_negative/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02542/study1_negative/image2.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01833/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01833/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01833/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01833/study1_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01833/study1_negative/image4.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01833/study1_negative/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01469/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01469/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01469/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01469/study1_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01469/study1_negative/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01844/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01844/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01844/study1_negative/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01844/study1_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01844/study1_negative/image2.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01564/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01564/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01564/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01564/study1_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01564/study1_negative/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01949/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01949/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01949/study1_negative/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01949/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01949/study1_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01949/study1_negative/image4.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01487/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01487/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01487/study1_negative/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01487/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01487/study1_negative/image3.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01513/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01513/study1_negative/
#  extracting: /content/MURA-v1.1/train/XR_SHOULDER/patient01513/study1_negative/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01513/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01513/study1_negative/image3.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02008/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02008/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02008/study1_negative/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02091/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02091/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02091/study1_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02091/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02091/study1_negative/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00631/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00631/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00631/study1_positive/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00631/study1_positive/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02105/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02105/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02105/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02105/study1_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02105/study1_negative/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02172/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02172/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02172/study1_negative/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02172/study1_negative/image4.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02172/study1_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02172/study1_negative/image2.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00646/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00646/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00646/study1_positive/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00646/study1_positive/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00646/study1_positive/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01059/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01059/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01059/study1_positive/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01154/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01154/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01154/study1_positive/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01154/study1_positive/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01154/study1_positive/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01123/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01123/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01123/study1_positive/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01123/study1_positive/image2.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02075/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02075/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02075/study1_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02075/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02075/study1_negative/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00741/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00741/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00741/study1_positive/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00741/study1_positive/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00741/study1_positive/image3.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00736/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00736/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00736/study1_positive/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00736/study1_positive/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00736/study1_positive/image2.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02002/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02002/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02002/study1_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02002/study1_negative/image4.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02002/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02002/study1_negative/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02196/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02196/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02196/study1_negative/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02196/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02196/study1_negative/image3.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02178/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02178/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02178/study1_negative/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02178/study1_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02178/study1_negative/image2.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01024/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01024/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01024/study1_positive/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01024/study1_positive/image4.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01024/study1_positive/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01024/study1_positive/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01053/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01053/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01053/study1_positive/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01053/study1_positive/image4.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01053/study1_positive/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01053/study1_positive/image2.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01129/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01129/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01129/study1_positive/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01129/study1_positive/image2.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00371/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00371/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00371/study1_positive/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02445/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02445/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02445/study1_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02445/study1_negative/image4.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02445/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02445/study1_negative/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00292/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00292/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00292/study1_positive/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00292/study1_positive/image4.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00292/study1_positive/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00292/study1_positive/image2.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02432/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02432/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02432/study1_negative/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02432/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02432/study1_negative/image3.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00306/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00306/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00306/study1_positive/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00306/study1_positive/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02548/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02548/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02548/study1_negative/image4.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02548/study1_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02548/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02548/study1_negative/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01414/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01414/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01414/study1_positive/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01414/study1_positive/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01414/study1_positive/image4.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01414/study1_positive/image2.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01580/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01580/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01580/study1_negative/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01580/study1_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01580/study1_negative/image2.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01839/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01839/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01839/study1_negative/image4.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01839/study1_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01839/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01839/study1_negative/image5.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01839/study1_negative/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01463/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01463/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01463/study1_negative/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01463/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01463/study1_negative/image3.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01943/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01943/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01943/study1_negative/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01943/study1_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01943/study1_negative/image2.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01519/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01519/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01519/study1_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01519/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01519/study1_negative/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01934/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01934/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01934/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01934/study1_negative/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01350/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01350/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01350/study1_positive/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01350/study1_positive/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01350/study1_positive/image4.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01350/study1_positive/image3.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01327/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01327/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01327/study1_positive/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01327/study1_positive/image2.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02295/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02295/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02295/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02295/study1_negative/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02301/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02301/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02301/study1_negative/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02301/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02301/study1_negative/image3.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00435/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00435/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00435/study1_positive/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00442/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00442/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00442/study1_positive/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00442/study1_positive/image2.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02376/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02376/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02376/study1_negative/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02376/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02376/study1_negative/image3.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00818/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00818/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00818/study1_positive/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00818/study1_positive/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00818/study1_positive/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00538/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00538/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00538/study1_positive/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00538/study1_positive/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00962/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00962/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00962/study1_positive/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00962/study1_positive/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00962/study1_positive/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02398/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02398/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02398/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02398/study1_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02398/study1_negative/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00915/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00915/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00915/study1_positive/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00915/study1_positive/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00881/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00881/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00881/study1_positive/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00881/study1_positive/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00881/study1_positive/image3.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01760/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01760/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01760/study1_negative/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01760/study1_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01760/study1_negative/image2.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01683/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01683/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01683/study1_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01683/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01683/study1_negative/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01717/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01717/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01717/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01717/study1_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01717/study1_negative/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00005/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00005/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00005/study1_positive/image1.png
# ...
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02552/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02552/study1_negative/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02525/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02525/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02525/study1_negative/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02525/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02525/study1_negative/image3.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00211/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00211/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00211/study1_positive/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00211/study1_positive/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00385/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00385/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00385/study1_positive/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00385/study1_positive/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00385/study1_positive/image4.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00385/study1_positive/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00288/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00288/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00288/study1_positive/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00288/study1_positive/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00288/study1_positive/image3.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02428/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02428/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02428/study1_negative/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02428/study1_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02428/study1_negative/image2.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01133/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01133/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01133/study1_positive/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01133/study1_positive/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01133/study1_positive/image2.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01144/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01144/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01144/study1_positive/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01144/study1_positive/image2.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01049/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01049/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01049/study1_positive/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01049/study1_positive/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01049/study1_positive/image2.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02162/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02162/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02162/study1_negative/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02162/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02162/study1_negative/image3.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00656/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00656/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00656/study1_positive/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02081/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02081/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02081/study1_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02081/study1_negative/image4.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02081/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02081/study1_negative/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00621/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00621/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00621/study1_positive/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02115/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02115/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02115/study1_negative/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02115/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02115/study1_negative/image4.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02115/study1_negative/image3.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02018/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02018/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02018/study1_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02018/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02018/study1_negative/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01139/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01139/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01139/study1_positive/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01139/study1_positive/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01139/study1_positive/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01043/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01043/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01043/study1_positive/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01034/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01034/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01034/study1_positive/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01034/study1_positive/image2.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02168/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02168/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02168/study1_negative/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02168/study1_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02168/study1_negative/image4.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02168/study1_negative/image2.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00726/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00726/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00726/study1_positive/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00726/study1_positive/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00726/study2_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00726/study2_positive/image4.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00726/study2_positive/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00726/study2_positive/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00726/study2_positive/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02012/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02012/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02012/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02012/study1_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02012/study1_negative/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02186/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02186/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02186/study1_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02186/study1_negative/image4.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02186/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02186/study1_negative/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02065/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02065/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02065/study1_negative/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02065/study1_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02065/study1_negative/image2.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00751/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00751/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00751/study1_positive/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00751/study1_positive/image4.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00751/study1_positive/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00751/study1_positive/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00751/study2_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00751/study2_negative/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00751/study2_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00751/study2_negative/image3.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01924/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01924/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01924/study1_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01924/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01924/study1_negative/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01953/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01953/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01953/study1_negative/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01953/study1_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01953/study1_negative/image4.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01953/study1_negative/image2.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01509/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01509/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01509/study1_negative/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01509/study1_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01509/study1_negative/image2.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01829/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01829/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01829/study1_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01829/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01829/study1_negative/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01473/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01473/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01473/study1_negative/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01404/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01404/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01404/study1_positive/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01404/study1_positive/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01404/study1_positive/image4.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01404/study1_positive/image2.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01590/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient01590/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01590/study1_negative/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01590/study1_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient01590/study1_negative/image2.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02558/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02558/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02558/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02558/study1_negative/image4.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02558/study1_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02558/study1_negative/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00282/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00282/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00282/study1_positive/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00282/study1_positive/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00282/study1_positive/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02422/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02422/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02422/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02422/study1_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02422/study1_negative/image1.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00316/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00316/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00316/study1_positive/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00316/study1_positive/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00316/study1_positive/image4.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00316/study1_positive/image2.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00361/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient00361/study1_positive/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00361/study1_positive/image1.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient00361/study1_positive/image2.png
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02455/
#    creating: /content/MURA-v1.1/train/XR_SHOULDER/patient02455/study1_negative/
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02455/study1_negative/image2.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02455/study1_negative/image4.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02455/study1_negative/image3.png
#   inflating: /content/MURA-v1.1/train/XR_SHOULDER/patient02455/study1_negative/image1.png

# %% [markdown]
# ### 1. Load Data and Split into Train/Val/Test Sets

# %%
def create_data_frame(filepath):
    df = pd.read_csv(filepath, names=['file_path', 'label'])
    df['body_part'] = df.apply(lambda x: x.file_path.split('/')[2][3:],axis=1)
    df['patient_id'] = df.apply(lambda x: x.file_path.split('/')[3][7:],axis=1)
    df['study_type'] = df.apply(lambda x: x.file_path.split('/')[4][:6],axis=1)
    return df

# %%
train_file_path = '/content/MURA-v1.1/train_labeled_studies.csv'
test_file_path = '/content/MURA-v1.1/valid_labeled_studies.csv'  # Because we do not have access to testing data, so use Val as Test
train_df = create_data_frame(train_file_path)
test_data = create_data_frame(test_file_path)

# %%
# Split training set into train/val - keep patients together
groups = train_df['patient_id']
gss = GroupShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
train_idx, val_idx = next(gss.split(train_df, groups=groups))

train_data = train_df.iloc[train_idx]
val_data = train_df.iloc[val_idx]

# %%
# Distribution of data set by class and label
body_part_label_counts_train = train_data.groupby(['label', 'body_part']).size().reset_index(name='counts')
body_part_label_counts_val = val_data.groupby(['label', 'body_part']).size().reset_index(name='counts')
body_part_label_counts_test = test_data.groupby(['label', 'body_part']).size().reset_index(name='counts')

# Plot
fig, axes = plt.subplots(1, 3, figsize=(18, 6), sharey=True)

# Plot for training data
sns.barplot(data=body_part_label_counts_train, x='body_part', y='counts', hue='label', ax=axes[0], palette='viridis')
axes[0].set_title('Training Distribution')

# Plot for validation data
sns.barplot(data=body_part_label_counts_val, x='body_part', y='counts', hue='label', ax=axes[1], palette='viridis')
axes[1].set_title('Validation Distribution')

# Plot for test data
sns.barplot(data=body_part_label_counts_test, x='body_part', y='counts', hue='label', ax=axes[2], palette='viridis')
axes[2].set_title('Test Distribution')

fig.tight_layout()
plt.show()

# %%
# Example X-ray
image_folder = train_data['file_path'].iloc[0]  # First patient
image_files = [os.path.join(image_folder, file) for file in os.listdir(image_folder)]

# Plot
fig, axes = plt.subplots(1, len(image_files), figsize=(18, 6), sharey=True)

for i, img_path in enumerate(image_files):
    image = Image.open(img_path)
    axes[i].imshow(image)
    axes[i].axis('off')

plt.show()

# %% [markdown]
# ### 2. Create Data Set and Data Loaders

# %%
from torch.utils.data import Dataset
from torchvision import transforms
import PIL.Image as Image
from torch.utils.data import DataLoader
import torch
from torchvision.datasets.folder import pil_loader
import torch
import torch.nn as nn
import torchvision.transforms as transforms
from torchvision.models import resnet18
from torch.utils.data import DataLoader, Dataset
import pandas as pd
from PIL import Image
import os
import re

# %%
class MuraDataset(Dataset):
    def __init__(self, df, transform=None):
        """
        Args:
            df (DataFrame): DataFrame containing file paths and labels.
            transform (callable, optional): Optional transform to be applied on an image.
        """
        self.df = df
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        image_folder = self.df.iloc[idx]['file_path']
        image_paths = []
        # Prevent .img error
        for file in os.listdir(image_folder):
          if re.match(r'image\d+\.png$', file.lower()):
            image_paths.append(os.path.join(image_folder, file))
        images = [Image.open(image_path).convert('L') for image_path in image_paths]  #Should we do Grayscale 'L' or 'LA' ?

        if self.transform:
            images = [self.transform(image) for image in images]

        label = self.df.iloc[idx]['label']
        #label = torch.from_numpy(np.asarray(label)).double().type(torch.FloatTensor)

        return images, label

# Define transformations
train_transform = transforms.Compose([
        transforms.Resize(224),
         transforms.RandomCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(10),
        transforms.ToTensor(),
        transforms.Normalize([0.456], [0.224])
    ])

val_transform = transforms.Compose([
        transforms.Resize(224),
        transforms.RandomCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.456], [0.224])
    ])

# Dataset and DataLoader
train_dataset = MuraDataset(df=train_data, transform=train_transform)
train_loader = DataLoader(dataset=train_dataset, batch_size=5, num_workers=2, pin_memory=True, collate_fn=lambda x: zip(*x), shuffle=True)  # Collate handles diff number of images per study
first_batch = next(iter(train_loader))
# Out:
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()

# %%
val_dataset = MuraDataset(df=val_data, transform=val_transform)
val_loader = DataLoader(dataset=val_dataset, batch_size=5, num_workers=2, pin_memory=True, collate_fn=lambda x: zip(*x), shuffle=False)

test_dataset = MuraDataset(df=test_data, transform=val_transform)
test_loader = DataLoader(dataset=test_dataset, batch_size=5, num_workers=2, pin_memory=True, collate_fn=lambda x: zip(*x), shuffle=False)


first_batch = next(iter(val_loader))
first_batch = next(iter(test_loader))

# %%
def show_images(batch):
    images, labels = batch
    batch_size = len(images)

    n_rows = sum(len(imgs) for imgs in images)
    if n_rows > 1:
        fig, axes = plt.subplots(n_rows, 1, figsize=(5, n_rows * 5))
        axes = axes.flatten()
    else:
        fig, axes = plt.subplots(figsize=(5, 5))
        axes = [axes]

    fig.subplots_adjust(hspace=0.5)
    current_row = 0
    for i in range(batch_size):
        for img in images[i]:
            ax = axes[current_row]
            luminance_channel = img[0, :, :]
            ax.imshow(luminance_channel, cmap='gray')
            ax.axis('off')
            ax.set_title(f'Label: {labels[i]}')
            current_row += 1
    plt.show()

first_batch = next(iter(train_loader))
# Uncomment to show images from one batch
show_images(first_batch)

# %%
first_batch = next(iter(train_loader))
images, label = first_batch

# %% [markdown]
# ### 3. Define Model

# %%
from torchvision.models import resnet18, ResNet18_Weights

class MultiViewCNN(nn.Module):
    def __init__(self):
        super(MultiViewCNN, self).__init__()
        self.base_model = resnet18(weights=ResNet18_Weights.DEFAULT)
        # Change the first conv layer to take 1 channel input
        self.base_model.conv1 = nn.Conv2d(1, 64, kernel_size=3, stride=1, padding=2, bias=False)
        self.base_model.fc = nn.Linear(self.base_model.fc.in_features, 1)  # Output a single probability per view

    def forward(self, x):
        batch_probabilities = []
        for views in x:
            view_probabilities = [torch.sigmoid(self.base_model(view.unsqueeze(0))) for view in views]
            view_probabilities = torch.cat(view_probabilities, dim=0)
            study_probability = torch.mean(view_probabilities, dim=0, keepdim=True)
            batch_probabilities.append(study_probability)

        batch_probabilities = torch.cat(batch_probabilities, dim=0)
        return batch_probabilities

# %% [markdown]
# ### Train Model

# %%
def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs=10):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for data in train_loader:
            images, labels = data
            # Move data to device
            labels = torch.tensor(labels).to(device)
            image_batches = [[img.to(device) for img in view] for view in images]

            optimizer.zero_grad()
            outputs = model(image_batches)
            loss = criterion(outputs, labels.float().unsqueeze(1))
            loss.backward()
            optimizer.step()

            running_loss += loss.item() * len(labels)

        train_loss = running_loss / len(train_loader.dataset)
        print(f'Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss:.4f}')

        # Validation phase
        model.eval()
        running_val_loss = 0.0
        correct = 0
        total = 0

        with torch.no_grad():
            for data in val_loader:
                images, labels = data
                image_batches = [[img.to(device) for img in view] for view in images]
                labels = torch.tensor(labels).to(device)

                outputs = model(image_batches)
                val_loss = criterion(outputs, labels.float().unsqueeze(1))
                running_val_loss += val_loss.item() * len(labels)

                predicted = outputs.round()
                total += labels.size(0)
                correct += (predicted == labels.float().unsqueeze(1)).sum().item()

        val_loss = running_val_loss / len(val_loader.dataset)
        accuracy = 100 * correct / total
        print(f'Epoch {epoch+1}/{num_epochs}, Validation Loss: {val_loss:.4f}, Accuracy: {accuracy:.2f}%')

    print('Finished Training')

# %%
# Train the model
model = MultiViewCNN()
criterion = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs=5)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 85.4MB/s]
# Epoch 1/5, Train Loss: 0.6805
# Epoch 1/5, Validation Loss: 0.6618, Accuracy: 62.82%
# Epoch 2/5, Train Loss: 0.6755
# Epoch 2/5, Validation Loss: 0.7784, Accuracy: 62.82%
# Epoch 3/5, Train Loss: 0.6733
# Epoch 3/5, Validation Loss: 0.6891, Accuracy: 58.34%
# Epoch 4/5, Train Loss: 0.6720
# Epoch 4/5, Validation Loss: 0.6912, Accuracy: 62.82%
# Epoch 5/5, Train Loss: 0.6695
# Epoch 5/5, Validation Loss: 0.8053, Accuracy: 62.82%
# Finished Training

# %% [markdown]
# ### Evaluating Model

# %%
# Testing phase
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

model.eval()
running_test_loss = 0.0
correct = 0
total = 0
y_hat = []
y = []

with torch.no_grad():
    for data in test_loader:
        images, labels = data
        # Track y values
        y.extend(list(labels))
        image_batches = [[img.to(device) for img in view] for view in images]
        labels = torch.tensor(labels).to(device)

        outputs = model(image_batches)
        test_loss = criterion(outputs, labels.float().unsqueeze(1))
        running_test_loss += test_loss.item() * len(labels)

        # Track probability outputs
        y_hat.extend([output for output_list in outputs.tolist() for output in output_list])
        predicted = outputs.round()
        total += labels.size(0)
        correct += (predicted == labels.float().unsqueeze(1)).sum().item()

test_loss = running_test_loss / len(test_loader.dataset)
accuracy = 100 * correct / total
print(f'Test Loss: {test_loss:.4f}, Accuracy: {accuracy:.2f}%')
# Out:
# Test Loss: 0.9090, Accuracy: 55.13%

# %%
test_data['y_hat_prob'] = y_hat
test_data['y_hat'] = round(test_data['y_hat_prob'])
test_data
# Out:
#                                               file_path  label body_part  \
# 0     MURA-v1.1/valid/XR_WRIST/patient11185/study1_p...      1     WRIST
# 1     MURA-v1.1/valid/XR_WRIST/patient11186/study1_p...      1     WRIST
# 2     MURA-v1.1/valid/XR_WRIST/patient11186/study2_p...      1     WRIST
# 3     MURA-v1.1/valid/XR_WRIST/patient11186/study3_p...      1     WRIST
# 4     MURA-v1.1/valid/XR_WRIST/patient11187/study1_p...      1     WRIST
# ...                                                 ...    ...       ...
# 1194  MURA-v1.1/valid/XR_FINGER/patient11965/study1_...      0    FINGER
# 1195  MURA-v1.1/valid/XR_FINGER/patient11855/study1_...      0    FINGER
# 1196  MURA-v1.1/valid/XR_FINGER/patient11966/study1_...      0    FINGER
# 1197  MURA-v1.1/valid/XR_FINGER/patient11967/study1_...      0    FINGER
# 1198  MURA-v1.1/valid/XR_FINGER/patient11738/study1_...      0    FINGER
#
#      patient_id study_type  y_hat_prob  y_hat
# 0         11185     study1    0.220915    0.0
# 1         11186     study1    0.268252    0.0
# 2         11186     study2    0.444732    0.0
# 3         11186     study3    0.086771    0.0
# 4         11187     study1    0.415701    0.0
# ...         ...        ...         ...    ...
# 1194      11965     study1    0.017068    0.0
# 1195      11855     study1    0.417226    0.0
# 1196      11966     study1    0.083990    0.0
# 1197      11967     study1    0.137641    0.0
# 1198      11738     study1    0.223442    0.0
#
# [1199 rows x 7 columns]

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, precision_recall_curve, roc_curve, auc
import matplotlib.pyplot as plt
import seaborn as sns

# %%
y = test_data['label'].values
y_hat = test_data['y_hat'].values
y_hat_prob = test_data['y_hat_prob'].values

# %%
# Calculate metrics
accuracy = accuracy_score(y, y_hat)
precision = precision_score(y, y_hat)
recall = recall_score(y, y_hat)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
# Out:
# Accuracy: 0.5512927439532944
# Precision: 0.0
# Recall: 0.0
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Confusion Matric
cm = confusion_matrix(y, y_hat)

sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', square=True,
            xticklabels=['Negative', 'Positive'], yticklabels=['Negative', 'Positive'])
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
# Precision-Recall curve
precision, recall, thresholds = precision_recall_curve(y, y_hat_prob)

plt.figure(figsize=(8, 6))
plt.plot(recall, precision, marker='.', label='Final Model')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend()
plt.grid(True)
plt.show()

# %%
# ROC curve
fpr, tpr, thresholds = roc_curve(y, y_hat_prob)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.grid(True)
plt.show()

# %%
# Metrics by body part

metrics = pd.DataFrame(columns=['body_part', 'precision', 'recall', 'accuracy'])
grouped = test_data.groupby('body_part')

metrics_list = []
for name, group in grouped:
    precision = precision_score(group['label'], group['y_hat'])
    recall = recall_score(group['label'], group['y_hat'])
    accuracy = accuracy_score(group['label'], group['y_hat'])
    metrics_list.append({'body_part': name, 'precision': precision, 'recall': recall, 'accuracy': accuracy})

metrics = pd.DataFrame(metrics_list)

# Plotting
plt.figure(figsize=(10, 8))
plt.plot(metrics['body_part'], metrics['precision'], label='Precision', marker='o')
plt.plot(metrics['body_part'], metrics['recall'], label='Recall', marker='o')
plt.plot(metrics['body_part'], metrics['accuracy'], label='Accuracy', marker='o')
plt.xlabel('Body Part')
plt.ylabel('Metrics')
plt.ylim([0,1])
plt.title('Precision, Recall, and Accuracy by Body Part')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Confusion Matrices by Body Part
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(16, 12))
fig.suptitle('Confusion Matrices by Body Part', fontsize=16)
axes = axes.flatten()

for idx, (name, group) in enumerate(grouped):
    cm = confusion_matrix(group['label'], group['y_hat'])
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=axes[idx])
    axes[idx].set_title(f'{name}')
    axes[idx].set_xlabel('Predicted labels')
    axes[idx].set_ylabel('True labels')

# Hide any unused subplots
for ax in axes[len(grouped):]:
    ax.axis('off')

plt.tight_layout()
plt.show()
